# %% [markdown]
# **IMPORTING PANDAS AND READING CSV FILE**

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/devilsboy/AIML-Lab-1/master/challenge-week-1/datasets_596958_1073629_Placement_Data_Full_Class.csv")

# %%
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# 8        9      M  73.00  Central  79.00  Central  Commerce     72.00
# 9       10      M  58.00  Central  70.00  Central  Commerce     61.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 11      12      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %% [markdown]
# **IMPORTING MATPLOTLIB**

# %%
import matplotlib.pyplot as plt

# %%
y = data["salary"]
x = data["degree_p"]

# %% [markdown]
# **LINE GRAPH**

# %%
plt.plot(x,y)

# %% [markdown]
# **BAR GRAPH**

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 215 artists>

# %% [markdown]
# **HISTOGRAM**

# %%
plt.hist(y)
# Out:
# C:\Users\sunee\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\sunee\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([84., 39., 17.,  2.,  3.,  0.,  2.,  0.,  0.,  1.]),
#  array([200000., 274000., 348000., 422000., 496000., 570000., 644000.,
#         718000., 792000., 866000., 940000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# **PIE CHART**

# %%
z = data[("sl_no")]
plt.pie(z)
# Out:
# ([<matplotlib.patches.Wedge at 0x205db94f5c0>,
# ...
#  [Text(1.0999999899321216, 0.00014882651876785052, ''),
#   Text(1.0999998389139471, 0.0005953060478283604, ''),
#   Text(1.099999184501938, 0.0013394383419941727, ''),
#   Text(1.099997422624096, 0.002381222447759174, ''),
#   Text(1.0999937075817314, 0.0037206559362968684, ''),
#   Text(1.0999869520546968, 0.005357733608398376, ''),
#   Text(1.0999758271111215, 0.007292446174239448, ''),
#   Text(1.0999587622253544, 0.009524778405123982, ''),
#   Text(1.099933945307142, 0.012054707008687056, ''),
#   Text(1.0998993227447762, 0.014882198277908031, ''),
#   Text(1.099852599473077, 0.018007205011202402, ''),
#   Text(1.0997912390620368, 0.021429663608888278, ''),
#   Text(1.0997124638333062, 0.025149490843339804, ''),
#   Text(1.0996132550205477, 0.029166579900902097, ''),
#   Text(1.099490352975365, 0.03348079619882452, ''),
#   Text(1.0993402574282105, 0.03809197287717981, ''),
#   Text(1.0991592277935267, 0.042999906468945685, ''),
# ...

# %% [markdown]
# **SCATTER PLOT**

# %%
plt.scatter(x,y)

# %% [markdown]
# **POLAR POT**

# %%
plt.polar(x,y)
# Out:
# C:\Users\sunee\Anaconda3\lib\site-packages\matplotlib\projections\polar.py:63: RuntimeWarning: invalid value encountered in less
#   mask = r < 0

# %% [markdown]
# **STEM PLOT**

# %%
plt.stem(x,y)
# Out:
# <StemContainer object of 3 artists>

# %% [markdown]
# **OPENING IMAGE FILE**

# %%
from PIL import Image
import requests
from io import BytesIO

response = requests.get('https://i.imgur.com/ExdKOOz.png')
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=200x200 at 0x205DCC27F28>

# %% [markdown]
# **IMAGE SIZE**

# %%
print(img.size)
# Out:
# (200, 200)

# %% [markdown]
# **IMPORTING VIDEO FILE**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
vid = cv.VideoCapture("/content/drive/My Drive/AIML-Lab-1.mp4")

while(1):
  ret, frame = vid.read()
  cv2_imshow(frame)

  if cv.waitKey(1) & 0xFF == ord('q') or ret==False :
       cap.release()
       cv.destroyAllWindows()
       break
   
  cv2_imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-87f513eea50e> in <module>
# ----> 1 import cv2 as cv
#       2 from google.colab.patches import cv2_imshow
#       3 vid = cv.VideoCapture("/content/drive/My Drive/AIML-Lab-1.mp4")
#       4
#       5 while(1):
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# **IMPORTING AUDIO FILE**

# %%
from IPython.display import Audio
Audio(url="https://file-examples-com.github.io/uploads/2017/11/file_example_MP3_700KB.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="https://file-examples-com.github.io/uploads/2017/11/file_example_MP3_700KB.mp3" type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **READING TEXT DATA**

# %%
text = pd.read_csv("https://raw.githubusercontent.com/devilsboy/AIML-Lab-1/master/README.txt")
print(text)
# Out:
#                                       # AIML-Lab-1
# 0  CSV file and .ipynb file for the Lab Assignment
# 1                                    All AIML Labs
